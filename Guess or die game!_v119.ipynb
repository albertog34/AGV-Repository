# %% [markdown]
# <b><span style="color:#3498DB;font-family:verdana;font-size:18px"> PART 1: DEFINING THE FUNCTIONS </span></b>

# %%
## Let's try to create a game in which the user has a total of 3 chances to guess a random number generated from 1 to 100.
# As long as the user does not guess the number, we will give him/her clues until he/she finally manages to guess it.

# We start by welcoming the user:

import PySimpleGUI as sg
from random import randint

font = ("Calibri", 12)
sg.theme("DarkTeal6")
sg.set_options(font=font)

global target_number
target_number = int(randint(1, 100))
    

def hello():

    layout = [
        [
            sg.Text(
                """Welcome to the Guess or die game!

    Will you be able to guess a number from 1 to 100 from a maximum of 3 clues?

    Let's check it out!
    """,
                justification="center",
            )
        ],
        [sg.Button("Let's go!"), sg.Button("Not now")],
        [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\detective.png")],
    ]
    window = sg.Window("Guess or die game", layout)
    global event
    event = window.read()[0]
    window.close()


def goodbye():

    layout2 = [
        [sg.Text("See you soon!")],
        [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\gooodbye.png")],
        [sg.Button("Exit")],
    ]
    window2 = sg.Window("GOODBYE!", layout2)
    global event
    event = window2.read()[0]
    window2.close()


def asknumber():

    while True:

        layout3 = [
            [sg.Text("Please enter your number")],
            [sg.Text("Number", size=(15, 3)), (sg.InputText())],
            [sg.Submit(), sg.Cancel()],
        ]
        window3 = sg.Window("Guess or die game", layout3)
        global output
        global event
        event, output = window3.read()
        window3.close()

        if event == "Cancel" or event == sg.WIN_CLOSED:
            break

        try:
            output = int(output[0])
            break

        except:

            layout4 = [
                [sg.Text("Is that a number???? NO! Please, enter a valid number")],
                [
                    sg.Image(
                        filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\errorrr.png"
                    )
                ],
                [sg.Button("Ok")],
            ]
            window4 = sg.Window("ERROR", layout4)
            event = window4.read()[0]
            window4.close()


def clue1():

    # The next thing we will do is to start building the tracks that will be shown to the user. We will start with the first one
    # We'll start simple, we'll tell the user if the number is odd or even.

    if target_number % 2 == 0:

        layout4 = [
            [sg.Text("The number we are looking for is even")],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window4 = sg.Window("Clue1", layout4)
        global event
        event = window4.read()[0]
        window4.close()

    else:

        layout4 = [
            [sg.Text("The number we are looking for is odd")],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window4 = sg.Window("CLUE 1", layout4)
        event = window4.read()[0]
        window4.close()


def clue2():

    # Since the user has not guessed correctly, we will go for the second clue. This time, we'll make him think a bit harder and tell him all the numbers by which it is divisible.

    divisible_numbers = []

    for i in range(1, target_number):
        if target_number % i == 0:
            divisible_numbers.append(i)
        else:
            pass

    # Once this has been done, we show the user the results

    if len(divisible_numbers) > 1:

        layout5 = [
            [
                sg.Text(
                    f"""The number we are looking for is divisible by these 2 numbers {random.choices(divisible_numbers,k=2)}
                    
                    (CAREFUL: THESE ARE NOT ALL ITS DIVISORS):
                    """
                )
            ],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window5 = sg.Window("Clue2", layout5)
        global event
        event = window5.read()[0]
        window5.close()

    else:

        layout5 = [
            [sg.Text("The number we are looking for is prime!")],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window5 = sg.Window("CLUE 2", layout5)
        event = window5.read()[0]
        window5.close()


def clue3():

    # Since the user still can't guess, we give the last clue of all. On this occasion, we are going to narrow down a range of +-10 numbers between which the target is to be found.

    lower_number_interval = int(target_number * (1 - (int(randint(0, 10)) / 100)))
    higher_number_interval = int(target_number * (1 + (int(randint(0, 10)) / 100)))

    layout6 = [
        [
            sg.Text(
                f"I'll make it easy for you: your number is between {lower_number_interval} and {higher_number_interval}, both inclusive"
            )
        ],
        [
            sg.Image(
                filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
            )
        ],
        [sg.Button("Continue")],
    ]
    window6 = sg.Window("CLUE 3", layout6)
    global event
    event = window6.read()[0]
    window6.close()


def clue4():

    if len(str(target_number)) == 1:

        layout15 = [
            [sg.Text("The number we are looking for has only one digit!")],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window15 = sg.Window("CLUE 4", layout15)
        event = window15.read()[0]
        window15.close()

    elif len(str(target_number)) == 2:

        if int(str(target_number)[0]) > int(str(target_number)[1]):

            layout15 = [
                [
                    sg.Text(
                        "The first digit of the number is greater than the second digit of the number"
                    )
                ],
                [
                    sg.Image(
                        filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                    )
                ],
                [sg.Button("Ok")],
            ]
            window15 = sg.Window("CLUE 4", layout15)
            event = window15.read()[0]
            window15.close()

        elif int(str(target_number)[0]) < int(str(target_number)[1]):

            layout15 = [
                [
                    sg.Text(
                        "The second digit of the number is greater than the second first of the number"
                    )
                ],
                [
                    sg.Image(
                        filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                    )
                ],
                [sg.Button("Ok")],
            ]
            window15 = sg.Window("CLUE 4", layout15)
            event = window15.read()[0]
            window15.close()

        else:

            layout15 = [
                [sg.Text("Both digits of the number are the same!")],
                [
                    sg.Image(
                        filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                    )
                ],
                [sg.Button("Ok")],
            ]
            window15 = sg.Window("CLUE 4", layout15)
            event = window15.read()[0]
            window15.close()

    else:

        layout15 = [
            [sg.Text("That's not possible!")],
            [
                sg.Image(
                    filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\deteective.png"
                )
            ],
            [sg.Button("Ok")],
        ]
        window15 = sg.Window("CLUE 4", layout15)
        event = window15.read()[0]
        window15.close()
        

def congratulations():

    layout7 = [
        [
            sg.Text(
                f"Congratulations! The number we were looking for was {target_number}!"
            )
        ],
        [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\ok.png")],
        [sg.Button("Finish attemp")],
    ]
    window7 = sg.Window("CONGRATULATIONS!", layout7)
    global event
    event = window7.read()[0]
    window7.close()

    layout8 = [
        [sg.Text("The game is end. Do you want to try again?")],
        [sg.Button("Of course!"), sg.Button("Not now")],
    ]
    window8 = sg.Window("REPEAT?", layout8)
    event = window8.read()[0]
    window8.close()


def closing():

    layout9 = [
        [
            sg.Text(
                "Man, you're a damn loser.... Seriously, do something other than maths ;)"
            )
        ],
        [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\loser.png")],
        [sg.Button("Continue")],
    ]
    window9 = sg.Window("NO WAY!", layout9)
    global event
    event = window9.read()[0]
    window9.close()

    layout10 = [
        [sg.Text(f"The number we were looking for was {target_number}!")],
        [sg.Button("Finish attemp")],
    ]
    window10 = sg.Window("NO WAY!", layout10)
    event = window10.read()[0]
    window10.close()

    layout11 = [
        [sg.Text("The game is end. Do you want to try again?")],
        [sg.Button("Let's go!"), sg.Button("Not now"),],
    ]
    window11 = sg.Window("REPEAT?", layout11)
    event = window11.read()[0]
    window11.close()


def error():

    if game_phase <= 1:

        layout12 = [
            [
                sg.Text(
                    "Wrong! It's difficult with just one clue... isn't it? Let's go for the second one!"
                )
            ],
            [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\Robot.png")],
            [sg.Button("Continue")],
        ]
        window12 = sg.Window("ERROR", layout12)
        global event
        event = window12.read()[0]
        window12.close()

    elif game_phase == 2:

        layout14 = [
            [
                sg.Text(
                    "You're getting close to bankruptcy, huh? Need a third clue to guess it? What a low IQ..."
                )
            ],
            [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\Robot.png")],
            [sg.Button("Continue")],
        ]
        window14 = sg.Window("ERROR", layout14)
        event = window14.read()[0]
        window14.close()

    else:

        layout14 = [
            [sg.Text("Bro, you are RIDICULOUS. Are you going to guess it or not?")],
            [sg.Image(filename=r"C:\Users\Alberto Garcia\OneDrive\Imágenes\Robot.png")],
            [sg.Button("Continue")],
        ]
        window14 = sg.Window("ERROR", layout14)
        event = window14.read()[0]
        window14.close()

# %% [markdown]
# <b><span style="color:#3498DB;font-family:verdana;font-size:18px"> PART 2: DEFINING THE GAME </span></b>

# %%
import random
clues=[clue1,clue2,clue3,clue4]
random.shuffle(clues)

hello()

if event =="Cancel" or event==sg.WIN_CLOSED:
    
    goodbye()
    
else:

    while event=="Let's go!":

        clues[0]()

        if event == "Cancel" or event== sg.WIN_CLOSED:
            continue

        asknumber()

        if event == "Cancel" or event== sg.WIN_CLOSED:
            continue

        if output==target_number:

            congratulations()

            if event == "Cancel" or event== sg.WIN_CLOSED:
                continue        

        else:

            game_phase=1

            error()

            if event == "Cancel" or event== sg.WIN_CLOSED:
                continue       

            clues[1]()

            if event == "Cancel" or event== sg.WIN_CLOSED:
                continue       

            asknumber()

            if event == "Cancel" or event== sg.WIN_CLOSED:
                continue    

            if output==target_number:

                congratulations()

                if event == "Cancel" or event== sg.WIN_CLOSED:
                    continue

            else:

                game_phase+=1

                error()

                if event == "Cancel" or event== sg.WIN_CLOSED:
                    continue            

                clues[2]()

                if event == "Cancel" or event== sg.WIN_CLOSED:
                    continue

                asknumber()

                if event == "Cancel" or event== sg.WIN_CLOSED:
                    continue

                if output==target_number:
                    
                    congratulations()
                    
                else:
                    
                    game_phase+=1
                    
                    error()
                    
                    if event == "Cancel" or event== sg.WIN_CLOSED:
                        continue                    
                    
                    clues[3]()
                    
                    if event == "Cancel" or event== sg.WIN_CLOSED:
                        continue
                        
                    asknumber()
                    
                    if event == "Cancel" or event== sg.WIN_CLOSED:
                        continue
                        
                    if output==target_number:

                        congratulations()

                        if event == "Cancel" or event== sg.WIN_CLOSED:
                            continue
                            
                    else:

                        closing()

                        if event == "Cancel" or event== sg.WIN_CLOSED:
                            continue
    else:
        goodbye()
